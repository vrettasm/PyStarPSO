# %% [markdown]
# # Test Function for IntegerPSO
# ---
# Description:
#
# - Optimization (min)
# - Single-objective
# - Constraints (no)
# ---
#
# The general problem statement is given by:
#
# - $f(\mathbf{x}) = \|x\|_1 = \sum_i |x_i|$, with $x = (x_1, ...,  x_D) \in [-100, 100]^D$,
# where D is the corresponding dimension.
#
# Global minimum found at: $f(0, 0, ..., 0) = 0$.

# %% [markdown]
# ### First we import python libraries and set up the directory of our code.

# %%
import os, sys
import numpy as np

PROJECT_DIR = os.path.abspath('..')
sys.path.append(PROJECT_DIR)

# %% [markdown]
# ### Here we import all our custom GA code.

# %%
# Import main classes.
from star_pso.auxiliary.swarm import Swarm
from star_pso.auxiliary.particle import Particle
from star_pso.engines.integer_pso import IntegerPSO

# %% [markdown]
# ### Define the OneMax fitness function.

# %%
# Test function.
def fun_test1(x: np.typing.ArrayLike):
    
    # Compute the function value.
    f_val = np.sum(np.abs(x))

    # Condition for termination.
    solution_found = f_val == 0.0
    
    # Return the solution tuple.
    return -f_val, solution_found
# _end_def_

# %% [markdown]
# Here we set the PSO parameters.

# %%
# Random number generator.
rng = np.random.default_rng()

# Define the number of optimizing variables.
D = 20

# Define the number of particles.
N = min(5*D, 100)

# Sample the initial points randomly.
X_t0 = rng.integers(low=-100, high=100, endpoint=True, size=(N, D))

# Initial population.
swarm_t0 = Swarm([Particle(x) for x in X_t0])

# Create the IntegerPSO object that will carry on the optimization.
test_PSO = IntegerPSO(initial_swarm = swarm_t0, obj_func = fun_test1,
                      copy = True, x_min = -100, x_max = +100)

# %% [markdown]
# ### Optimization process.
#
# Here we call the PSO object. We set a number of parameters, such as the maximum iterations (i.e. epochs), tolerance for the fitness convergence, etc.

# %%
test_PSO.run(max_it = 2000,
             options = {"w0": 0.5, "c1": 2.05, "c2": 2.05, "fipso": True},
             reset_swarm = True, verbose = True, adapt_params = False)
# Out:
# Initial f_optimal = -678.0000
# Iteration:     1 -> f_optimal = -283.0000
# IntegerPSO finished in 65 iterations.
# Final f_optimal = 0.0000
# run: elapsed time = 0.155 seconds.

# %%
# Get the optimal solution from the PSO.
i_opt, f_opt, x_opt = test_PSO.get_optimal_values()

# Display the (final) optimal value.
print(f"Optimum Found: {abs(f_opt):.6f}, at iteration {i_opt}.\n")

# Display each gene value separately.
print("Best position:")
for i, xi in enumerate(x_opt, start=1):
    print(f"x{i} = {xi}")
# _end_for_
# Out:
# Optimum Found: 0.000000, at iteration 65.
#
# Best position:
# x1 = 0
# x2 = 0
# x3 = 0
# x4 = 0
# x5 = 0
# x6 = 0
# x7 = 0
# x8 = 0
# x9 = 0
# x10 = 0
# x11 = 0
# x12 = 0
# x13 = 0
# x14 = 0
# x15 = 0
# x16 = 0
# x17 = 0
# x18 = 0
# x19 = 0
# x20 = 0

# %% [markdown]
# ### End of file
